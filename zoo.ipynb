# %%
class Animal:
    def __init__(self, type, genre, poids, taille, couleur, enclos, se_deplacer):
        self.__type = type
        self.__genre = genre
        self.__poids = poids
        self.__taille = taille
        self.__couleur = couleur
        self.__enclos = enclos
        self.__se_deplacer = se_deplacer

    def se_deplacer(self, ):
        return None
    
    class Reptile (Animal):
        def se_deplacer(self): 
            print("Je rampe")
        def enclos(self):
            print("Vivarium")

    class Oiseau (Animal):
        def se_deplacer(self):
            print("Je vole")
        def enclos(self):
            print("Volière")
    
    class Mammifere (Animal):
        def se_deplacer(self):
            print("Je marche")
        def enclos(self):
            print("enclos")
    
    class Amphibien (Animal):
        def se_deplacer(self):
            print("Je nage")
        def enclos(self):
            print("Aquarium")

    def get_type (self):
        return self__type
    def 
        return         

    # def __str__(self):
    #     return "type: {}, genre: {}, poids:{}, taille:{}, couleur:{}, enclos:{}, se_deplacer:{}"\
    #         .format(self.type, self.genre, self.poids, self.taille, self.couleur, self.enclos)

        class Oiseau:
        
            self.type = oiseau
            self.famille = famille
            self.genre = genre
            self.poids = poids
            self.taille = taille
            self.couleur = couleur
            self.enclos = "volière"
            self.se_deplacer = "Je vole"
    

        class Mammifere:
            self.type = "Mammifère"
            self.genre = genre
            self.poids = poids
            self.taille = taille
            self.couleur = couleur
            self.enclos = "Enclos"
            self.se_deplacer = "Je marche"

        class Reptile:
            self.type = type
            self.genre = genre
            self.poids = poids  
            self.taille = taille
            self.couleur = couleur
            self.enclos = "Vivarium"
            self.se_deplacer = "Je rampe"

        class Amphibien:
            self.type = type
            self.genre = genre
            self.poids = poids
            self.taille = taille
            self.couleur = couleur
            self.enclos = "aquarium"
            self.se_deplacer = "Je nage"
 
if __name__ == "__main__":
    # Oiseau = Animal()
    # Mammifere = Animal()
    # Reptile = Animal()
    # Amphibien = Animal()


    
    perruche = Animal ("Oiseau","femelle", "35grammes", "18cm", "vert", "voilière", "je vole")
    éléphant = Animal ("Mammifère", "mâle", "5500kg", "3.2m", "gris", "bassin", "je marche")
    capucin = Animal ("Mammifère", "femelle", "3kg", "40cm", "marron", "volière", "je marche")
    python = Animal ("Reptile", "mâle", "70kg", "5m", "marron", "terrarium", "je rampe")
    panda_roux = Animal ("Mammifère", "femelle", "6kg", "60cm", "roux", "enclos", "je marche")
    condor = Animal ("Oiseau", "mâle", "12kg", "3.2m d'envergure", "noir et blanc", "volière", "je vole")
    chacal = Animal ("Mammifère", "femelle", "10kg", "45cm", "tacheté", "enclos", "je marche")
    giraffe = Animal ("Mammifère", "mâle", "1200kg", "5.5m", "tacheté", "enclos", "je marche")
    Axolotl = Animal ("Amphibien", "femelle", "150g", "25cm", "rose", "aquarium", "je nage")

print(perruche)
# Out:
#   Cell In[13], line 38
#     def get_taille (self)
#                          ^
# SyntaxError: expected ':'

# %% [markdown]
# def__str___ :
# def__repr__:
